# %% [markdown]
# # Fase 1: Exploración y Comprensión de los Datos

# %% [markdown]
# ### Estructura de las carpetas

# %% [raw]
# my_massive_data_project/
# │
# ├── data/
# │   ├── bronce/                                # Capa Bronze: Datos fuente sin modificar
# │   │   ├── person_1/
# │   │   │   ├── Streaming_History_Audio_2018_2015.json
# │   │   │   └── ... (un archivo por año de 2015 a 2026)
# │   │   │
# │   │   ├── person_2/
# │   │   │   ├── Streaming_History_Audio_2024-2026_2014-2023.json
# │   │   │   └── ... (archivos por rangos de fechas hasta 2026)
# │   │   │
# │   │   └── consolidated_raw.parquet/           # !! Añadido una vez que se concatenen los valores de ambos jsons
# │   │
# │   ├── silver/                               # Capa Silver: Datos limpios y estandarizados
# │   │   ├── spotify_clean.parquet/              # Formato optimizado para procesamiento en PySpark
# │   │   └── spotify_clean_delivery/             # CSV consolidado para entregable de la Fase 2
# │   │
# │   └── gold/                                 # Capa Gold: Matrices de características para ML
# │
# ├── notebooks/                         # Notebooks de Jupyter
# │   └── notebook.ipynb                          # Análisis exploratorio y limpieza de datos
# │
# └── dashboards/
#     ├── streamlit.py                            # Aplicación principal de Streamlit

# %% [markdown]
# # Fase 2: Limpieza y Consolidación

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, LongType, BooleanType
from pyspark.sql import functions as F

from matplotlib import pyplot as plt

# %%
# Create the spark session
spark = SparkSession.builder \
    .appName("MassiveDataSpotify") \
    .config("spark.driver.memory", "12g") \
    .config("spark.executor.memory", "12g") \
    .config("spark.master", "local[*]") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "true") \
    .config("spark.sql.session.timeZone", "UTC") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/25 03:08:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read the data from each dir

df_source_1 = spark.read \
    .option("multiline", "true") \
    .json("/app/data/bronze/data_source_1") \
    .withColumn("user_id", F.lit("source_1"))

df_source_2 = spark.read \
    .option("multiline", "true") \
    .json("/app/data/bronze/data_source_2") \
    .withColumn("user_id", F.lit("source_2"))

# %%
print("--- Numero de registros en cada df ---")
print(f"Origen 1: {df_source_1.count():,}")
print(f"Origen 2: {df_source_2.count():,}")
# Out:
# --- Numero de registros en cada df ---
# Origen 1: 262,824
# Origen 2: 53,866

# %%
# Consolidate in a single DataFrame
df_consolidated = df_source_1.unionByName(df_source_2)

# %%
print(f"Numero de registros totales: {df_consolidated.count():,}")
# Out:
# [Stage 8:===================================>                     (13 + 8) / 21]
# Numero de registros totales: 316,690

# %%
# Output the data as parquet
parquet_output_path = "../data/bronze/consolidated_raw.parquet"

df_consolidated.write \
    .mode("overwrite") \
    .parquet(parquet_output_path)

# %%
df_raw = spark.read.parquet("/app/data/bronze/consolidated_raw.parquet")

# %%
df_raw.printSchema()
# Out:
# root
#  |-- audiobook_chapter_title: string (nullable = true)
#  |-- audiobook_chapter_uri: string (nullable = true)
#  |-- audiobook_title: string (nullable = true)
#  |-- audiobook_uri: string (nullable = true)
#  |-- conn_country: string (nullable = true)
#  |-- episode_name: string (nullable = true)
#  |-- episode_show_name: string (nullable = true)
#  |-- incognito_mode: boolean (nullable = true)
#  |-- ip_addr: string (nullable = true)
#  |-- master_metadata_album_album_name: string (nullable = true)
#  |-- master_metadata_album_artist_name: string (nullable = true)
#  |-- master_metadata_track_name: string (nullable = true)
#  |-- ms_played: long (nullable = true)
#  |-- offline: boolean (nullable = true)
#  |-- offline_timestamp: long (nullable = true)
#  |-- platform: string (nullable = true)
#  |-- reason_end: string (nullable = true)
#  |-- reason_start: string (nullable = true)
#  |-- shuffle: boolean (nullable = true)
#  |-- skipped: boolean (nullable = true)
#  |-- spotify_episode_uri: string (nullable = true)
#  |-- spotify_track_uri: string (nullable = true)
#  |-- ts: string (nullable = true)
#  |-- user_id: string (nullable = true)

# %%
# Number of total registers

total_ingested = df_raw.count()

print(f"--- Numero de registros totales: {total_ingested:,} ---")
# Out:
# --- Numero de registros totales: 316,690 ---

# %%
# Drop the "ip_addr" column for data protection issues
df_raw = df_raw.drop("ip_addr")

# %%
# Show for the first 5 registers
df_raw.show(5, vertical=True)
# Out:
# -RECORD 0-------------------------------------------------
#  audiobook_chapter_title           | NULL
#  audiobook_chapter_uri             | NULL
#  audiobook_title                   | NULL
#  audiobook_uri                     | NULL
#  conn_country                      | MX
#  episode_name                      | NULL
#  episode_show_name                 | NULL
#  incognito_mode                    | false
#  master_metadata_album_album_name  | More Than a Friend
#  master_metadata_album_artist_name | girli
#  master_metadata_track_name        | More Than a Friend
#  ms_played                         | 17384
#  offline                           | true
#  offline_timestamp                 | 1674740124
#  platform                          | ios
#  reason_end                        | endplay
#  reason_start                      | trackdone
#  shuffle                           | true
#  skipped                           | true
#  spotify_episode_uri               | NULL
#  spotify_track_uri                 | spotify:track:5TI...
#  ts                                | 2023-01-26T15:12:30Z
#  user_id                           | source_1
# -RECORD 1-------------------------------------------------
#  audiobook_chapter_title           | NULL
#  audiobook_chapter_uri             | NULL
#  audiobook_title                   | NULL
#  audiobook_uri                     | NULL
#  conn_country                      | MX
#  episode_name                      | NULL
#  episode_show_name                 | NULL
#  incognito_mode                    | false
#  master_metadata_album_album_name  | Choke
#  master_metadata_album_artist_name | I DONT KNOW HOW B...
#  master_metadata_track_name        | Choke - Acoustic
#  ms_played                         | 16927
#  offline                           | true
#  offline_timestamp                 | 1674745950
#  platform                          | ios
#  reason_end                        | endplay
#  reason_start                      | playbtn
#  shuffle                           | true
#  skipped                           | true
#  spotify_episode_uri               | NULL
#  spotify_track_uri                 | spotify:track:7DA...
#  ts                                | 2023-01-26T15:12:47Z
#  user_id                           | source_1
# -RECORD 2-------------------------------------------------
#  audiobook_chapter_title           | NULL
#  audiobook_chapter_uri             | NULL
#  audiobook_title                   | NULL
#  audiobook_uri                     | NULL
#  conn_country                      | MX
#  episode_name                      | NULL
#  episode_show_name                 | NULL
#  incognito_mode                    | false
#  master_metadata_album_album_name  | Shakira: Bzrp Mus...
#  master_metadata_album_artist_name | Bizarrap
#  master_metadata_track_name        | Shakira: Bzrp Mus...
#  ms_played                         | 217195
#  offline                           | true
#  offline_timestamp                 | 1674745967
#  platform                          | ios
#  reason_end                        | trackdone
#  reason_start                      | clickrow
#  shuffle                           | true
#  skipped                           | false
#  spotify_episode_uri               | NULL
#  spotify_track_uri                 | spotify:track:4nr...
#  ts                                | 2023-01-26T15:16:23Z
#  user_id                           | source_1
# -RECORD 3-------------------------------------------------
#  audiobook_chapter_title           | NULL
#  audiobook_chapter_uri             | NULL
#  audiobook_title                   | NULL
#  audiobook_uri                     | NULL
#  conn_country                      | MX
#  episode_name                      | NULL
#  episode_show_name                 | NULL
#  incognito_mode                    | false
#  master_metadata_album_album_name  | Listen Up! The Of...
#  master_metadata_album_artist_name | Shakira
#  master_metadata_track_name        | Waka Waka (This T...
#  ms_played                         | 202625
#  offline                           | true
#  offline_timestamp                 | 1674746183
#  platform                          | ios
#  reason_end                        | trackdone
#  reason_start                      | trackdone
#  shuffle                           | true
#  skipped                           | false
#  spotify_episode_uri               | NULL
#  spotify_track_uri                 | spotify:track:6bN...
#  ts                                | 2023-01-26T15:19:45Z
#  user_id                           | source_1
# -RECORD 4-------------------------------------------------
#  audiobook_chapter_title           | NULL
#  audiobook_chapter_uri             | NULL
#  audiobook_title                   | NULL
#  audiobook_uri                     | NULL
#  conn_country                      | MX
#  episode_name                      | NULL
#  episode_show_name                 | NULL
#  incognito_mode                    | false
#  master_metadata_album_album_name  | Loba
#  master_metadata_album_artist_name | Shakira
#  master_metadata_track_name        | Loba
#  ms_played                         | 94869
#  offline                           | true
#  offline_timestamp                 | 1674746385
#  platform                          | ios
#  reason_end                        | fwdbtn
#  reason_start                      | trackdone
#  shuffle                           | true
#  skipped                           | true
#  spotify_episode_uri               | NULL
#  spotify_track_uri                 | spotify:track:30X...
#  ts                                | 2023-01-26T15:21:21Z
#  user_id                           | source_1
# only showing top 5 rows

# %%
# Count the original number of nulls
print("--- Conteo de valores NULL nativos por columna ---")
df_raw.select([
    F.count(F.when(F.col(c).isNull(), c)).alias(c) 
    for c in df_raw.columns
]).show(vertical=True)
# Out:
# --- Conteo de valores NULL nativos por columna ---
# [Stage 17:=========================>                               (5 + 6) / 11]
# -RECORD 0-----------------------------------
#  audiobook_chapter_title           | 316690
#  audiobook_chapter_uri             | 316690
#  audiobook_title                   | 316690
#  audiobook_uri                     | 316690
#  conn_country                      | 0
#  episode_name                      | 316470
#  episode_show_name                 | 316470
#  incognito_mode                    | 0
#  master_metadata_album_album_name  | 220
#  master_metadata_album_artist_name | 220
#  master_metadata_track_name        | 220
#  ms_played                         | 0
#  offline                           | 0
#  offline_timestamp                 | 140602
#  platform                          | 0
#  reason_end                        | 0
#  reason_start                      | 0
#  shuffle                           | 0
#  skipped                           | 0
#  spotify_episode_uri               | 316470
#  spotify_track_uri                 | 220
#  ts                                | 0
#  user_id                           | 0

# %%
# Cleaning nulls
garbage_text_values = ["nan", "null", "na", "", "none", " "]
string_columns = [field.name for field in df_raw.schema if isinstance(field.dataType, StringType)]

df_cleaned = df_raw
for col_name in string_columns:
    df_cleaned = df_cleaned.withColumn(
        col_name,
        F.when(
            F.lower(F.trim(F.col(col_name))).isin(garbage_text_values) | F.col(col_name).isNull(),
            F.lit(None).cast(StringType())
        ).otherwise(F.col(col_name))
    )

df_cleaned = df_cleaned.dropna(subset=["ts", "ms_played"])

df_cleaned = df_cleaned.filter((F.col("ms_played").isNotNull()) & (F.col("ms_played") > 0))

null_fill_blueprint = {
    "master_metadata_track_name": "Unknown Track",
    "master_metadata_album_artist_name": "Unknown Artist",
    "master_metadata_album_album_name": "Unknown Album",
    "platform": "Unknown Platform",
    "conn_country": "Unknown Country",
    "episode_name": "Not A Podcast",
    "episode_show_name": "Not A Podcast",
    "spotify_episode_uri": "Not A Podcast",
    "reason_start": "unknown",
    "reason_end": "unknown",
    "offline_timestamp": 0
}

print(f"--- Numero de valores nulos dentro del dataset ---")
df_cleaned.select([
    F.count(F.when(F.col(c).isNull(), c)).alias(c) 
    for c in df_cleaned.columns
]).show(vertical=True)

df_cleaned = df_cleaned.fillna(null_fill_blueprint)
# Out:
# --- Numero de valores nulos dentro del dataset ---
# [Stage 20:==========>                                              (2 + 9) / 11]
# -RECORD 0-----------------------------------
#  audiobook_chapter_title           | 309270
#  audiobook_chapter_uri             | 309270
#  audiobook_title                   | 309270
#  audiobook_uri                     | 309270
#  conn_country                      | 0
#  episode_name                      | 309054
#  episode_show_name                 | 309054
#  incognito_mode                    | 0
#  master_metadata_album_album_name  | 216
#  master_metadata_album_artist_name | 216
#  master_metadata_track_name        | 216
#  ms_played                         | 0
#  offline                           | 0
#  offline_timestamp                 | 135618
#  platform                          | 0
#  reason_end                        | 0
#  reason_start                      | 0
#  shuffle                           | 0
#  skipped                           | 0
#  spotify_episode_uri               | 309054
#  spotify_track_uri                 | 216
#  ts                                | 0
#  user_id                           | 0

# %%
# Remove duplicated values
total_duplicates = total_ingested - df_cleaned.dropDuplicates(["ts", "user_id"]).count()
print(f"Total de registros duplicados detectados: {total_duplicates:,}")

df_cleaned = df_cleaned.dropDuplicates(["ts", "user_id"])

# %%
# Add dates, year, month, day of the week, hour, and minutes columns to the df
df_cleaned = df_cleaned \
    .withColumn("date_timestamp", F.to_timestamp("ts")) \
    .withColumn("readable_date", F.to_date("date_timestamp")) \
    .withColumn("year", F.year("date_timestamp")) \
    .withColumn("mont", F.month("date_timestamp")) \
    .withColumn("day_of_week", F.dayofweek("date_timestamp")) \
    .withColumn("hour", F.hour("date_timestamp")) \
    .withColumn("min_played", F.round(F.col("ms_played") / 60000, 2))

# %%
# Normalize song name, artist, and album name
text_targets = ["master_metadata_track_name", "master_metadata_album_artist_name", "master_metadata_album_album_name"]
for text_col in text_targets:
    df_cleaned = df_cleaned.withColumn(
        text_col,
        F.trim(F.regexp_replace(F.col(text_col), r"[\r\n\t]", " "))
    )

# %%
# Save cleaned DataFrame to parquet
df_cleaned.write.mode("overwrite").parquet("/app/data/silver/spotify_clean.parquet")

# Export to csv
df_cleaned.coalesce(1).write \
    .mode("overwrite") \
    .option("header", "true") \
    .option("encoding", "UTF-8") \
    .csv("/app/data/silver/spotify_clean_delivery")

# %%
print(f"Numero de registros despues de la limpieza: {df_cleaned.count():,}")

# %%
# Display of the data after being cleaned
df_cleaned.show(5, vertical=True)

# %% [markdown]
# # Fase 3: Análisis Exploratorio (EDA)

# %%
df = spark.read.parquet("/app/data/silver/spotify_clean.parquet")

# %% [markdown]
# ## Analisis 1: Patrones Temporales

# %%
# Count of artists and songs
artists_count = df.select("master_metadata_album_artist_name").distinct().count()
songs_count = df.select("spotify_track_uri").distinct().count()

print(f"Total de artistas unicos escuchados: {artists_count:,}")
print(f"Total de canciones unicas escuchadas: {songs_count:,}")

# Most listened artist
top_artist = df.filter(F.col("master_metadata_album_artist_name") != "Unknown Artist") \
    .groupBy("master_metadata_album_artist_name") \
    .count() \
    .orderBy(F.col("count").desc()) \
    .first()

print(f"Artista más escuchado: {top_artist['master_metadata_album_artist_name']} ({top_artist['count']:,} reproducciones)")

# Most listened song
top_song = df.filter(F.col("master_metadata_track_name") != "Unknown Track") \
    .groupBy("master_metadata_track_name", "master_metadata_album_artist_name") \
    .count() \
    .orderBy(F.col("count").desc()) \
    .first()

print(f"Canción más escuchada: '{top_song['master_metadata_track_name']}' de {top_song['master_metadata_album_artist_name']} ({top_song['count']:,} reproducciones)")

# %% [markdown]
# ### Distribución de escucha por hora del día

# %%
df_hora = df.groupBy("hora").count().orderBy("hora").toPandas()

# %%
'''
Analisis 1: Patrones Temporales
- Distribución de escucha por hora del día
- Actividad por día de la semana
- Tendencia mensual de consumo
- Mapa de calor día x hora
- Identifica tus horas y días pico
- Total de artistas únicos escuchados
- Total de canciones únicas escuchadas
- Artista más escuchado: Nombre (# reproducciones)
- Canción más escuchada: Nombre (# reproducciones)

Analisis 2: Top Contenido
- Top 20 artistas y canciones más reproducidas
- Diversidad músical por mes (o año)
- Tasa de completación vs skip
- Análiss de concentración musical (GENEROS O ARTISTAS)
- Visualizaciones de barras horizontales

Analisis 3: Comportamiento y Sesiones
- Analisis de duracion de sesiones
- Comportamiento de skip (completas/parciales/saltadas)
- Tendencia de descubrimiento musical
- Patrones de inicio de sesiones
'''
